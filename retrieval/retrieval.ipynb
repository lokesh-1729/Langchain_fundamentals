# %%
print("hello world")
# Out:
# hello world

# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader("atomic_summary.pdf")

# %%
pages=loader.load_and_split()

# %%
pages[0].page_content
# Out:
# 'A SUMMARY OF ATOMIC HABITS \nBY  \nJAMES CLEAR \n \nThe Book in Three Sentences \n1. An atomic habit is a regular practice or routine that is not only small and easy to do but is also the   \nsource of incredible power, an element of a larger system of intentional growth. \n2. Bad habits repeat themselves again and again not because we don’t want to change, but because we \nhave the wrong process for change to occur. \n3. Changes that seem small and unimportant at first will reap a greater reward overtime. \n \nThe Book’s Five Big Ideas \n1. Good habits are the small actions of self-improvement.  \n2. If you want better results, then forget about setting goals. Focus on the process instead.  \n3. The most effective way to change your habits is to focus not on what you want to achieve, but on who \nyou desire to become.  \n4. The Four Laws of Behavior Change are a simple set of rules we can use to build better habits. They are (1) \nmake it obvious, (2) make it attractive, (3) make i
# ...

# %%
#we can load frm web pages as well
from langchain_community.document_loaders import WebBaseLoader
URL="https://www.databricks.com/product/artificial-intelligence?scid=7018Y000001f8FIQAY&utm_medium=paid+search&utm_source=google&utm_campaign=23266805940&utm_adgroup=188704480693&utm_content=product&utm_offer=ai-agents&utm_ad=784499983358&utm_term=artificial%20intelligence%20agents&gad_source=1&gad_campaignid=23266805940&gbraid=0AAAAABYBeAjswpev7LdAQC5b1fYxXkWUU&gclid=CjwKCAiA9aPKBhBhEiwAyz82JwsI3nsFinRH5wHJokbbH4roNM_D2MAPlDhmyAUYKFLQC2iFi_cjzhoCr8YQAvD_BwE"

# %%
web_loader=WebBaseLoader(URL)
import bs4
data=web_loader.load()

# %%
data
# Out:
# [Document(metadata={'source': 'https://www.databricks.com/product/artificial-intelligence?scid=7018Y000001f8FIQAY&utm_medium=paid+search&utm_source=google&utm_campaign=23266805940&utm_adgroup=188704480693&utm_content=product&utm_offer=ai-agents&utm_ad=784499983358&utm_term=artificial%20intelligence%20agents&gad_source=1&gad_campaignid=23266805940&gbraid=0AAAAABYBeAjswpev7LdAQC5b1fYxXkWUU&gclid=CjwKCAiA9aPKBhBhEiwAyz82JwsI3nsFinRH5wHJokbbH4roNM_D2MAPlDhmyAUYKFLQC2iFi_cjzhoCr8YQAvD_BwE', 'title': 'Production-quality ML and GenAI | Databricks', 'description': 'Mosaic AI helps you build, deploy, evaluate and govern production-quality AI agent systems and ML apps — from predictive ML models to the latest GenAI solutions.', 'language': 'en-US'}, page_content='Production-quality ML and GenAI | DatabricksSkip to main contentBuild production AI agents optimized on your dataExplore Agent BricksLoginWhy Databricks DiscoverFor ExecutivesFor Startups Lakehouse Architecture Mosaic ResearchCustomer
# ...
