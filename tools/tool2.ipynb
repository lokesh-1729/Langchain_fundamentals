# %%
from langchain_community.tools.tavily_search import TavilySearchResults
import os

# %%
print("hello")

# %%
TAVILY_SEARCH_API=os.getenv("TAVILY_API_KEY")

# %%
tool=TavilySearchResults()
response=tool.invoke({"query":"when is the next ipl"})

# %%
print(response)

# %%
len(response)

# %%
response[0]['url']
response[0]['content']
