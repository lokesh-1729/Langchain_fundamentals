# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_core.prompts import ChatPromptTemplate,MessagesPlaceholder, PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.runnables import ConfigurableField

# %%
model=ChatOpenAI(model_name="gpt-3.5-turbo").configurable_fields(
    model_name=ConfigurableField(
        id="model_name",
        name="model_name",
        description="The GPT model to use for chat",
    )
)

# %%
prompt=PromptTemplate.from_template("write a haiku on {subject}")

# %%
chain=prompt|model

# %%
chain.invoke({"subject":"cat"})
# Out:
# AIMessage(content='Soft fur, sharp green eyes\nPurring, playful, graceful leap\nFeline friend so wise', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 13, 'total_tokens': 33, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-Cpp8f1iiYRzkvdzmMdyMf2Gs08FQm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b49a8-8b7e-7413-80c8-8c34d7c7f395-0', usage_metadata={'input_tokens': 13, 'output_tokens': 20, 'total_tokens': 33, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
chain.with_config(configurable={"model_name":"gpt-4"}).invoke({"subject":"cat"})
# Out:
# AIMessage(content='Whiskers twitch, eyes gleam,\nPurring softly, dream filled sleep,\nGrace in quiet leaps.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 13, 'total_tokens': 35, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CppB9aMXNWgIzgsJLVGTO8OpnPwch', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b49aa-e613-7592-8baa-48dd7d17cca7-0', usage_metadata={'input_tokens': 13, 'output_tokens': 22, 'total_tokens': 35, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
