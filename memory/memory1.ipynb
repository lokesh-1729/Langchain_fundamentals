# %%
print("hello world")
# Out:
# hello world

# %%
#short term memory for the session stored in ram
#Long term memory we externalise th data out of our application

# %%
#choosing redis to store memory in this session

# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_core.prompts import ChatPromptTemplate,MessagesPlaceholder
from langchain_openai import ChatOpenAI
model=ChatOpenAI()
prompt=ChatPromptTemplate.from_messages(
    [
        ("system","you are an assistant who's goood at {ability}, Respond in 20 word or fewer"),
        MessagesPlaceholder(variable_name="history"),
        ("human","{input}"),
        
    ]
)
base_chain=prompt|model

# %%
history=[
    ("human","what's a right angled triangle"),
    ("ai","A right angle triangle has one angle of 90 degrees, making it the largest angle in the triangle.")
]

# %%
base_chain.invoke(
    {"ability":"math","input":"what is a right angle triangle?",}
)
# Out:
# AIMessage(content='A right angle triangle has one angle of 90 degrees, making it the largest angle in the triangle.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 36, 'total_tokens': 57, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CpoqFr7ovJYVJvGiBm4B9HxeQo37g', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b4997-1dc1-73b2-a532-48eb7f8f0360-0', usage_metadata={'input_tokens': 36, 'output_tokens': 21, 'total_tokens': 57, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
base_chain.invoke(
    {"ability":"math","input":"what are the other types","history":history},
)
# Out:
# AIMessage(content='Acute triangle, all angles <90 degrees.\nObtuse triangle, one angle >90 degrees.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 69, 'total_tokens': 90, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-Cpozr2jS9Gj6ObuNzRfa0Bl6zmgPp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b49a0-367c-7793-bae5-b4e0a4029d00-0', usage_metadata={'input_tokens': 69, 'output_tokens': 21, 'total_tokens': 90, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
#from langchain core we can import message place holder taht will kep the messages in place that willl be helpful to track history
