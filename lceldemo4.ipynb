# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnablePassthrough

# %%
prompt=ChatPromptTemplate.from_template("""
you are a helpful assistant on {topic},
 answer the following question:{question}""")

# %%
llm=ChatOpenAI()
output_parser=StrOutputParser()

# %%
chain=prompt|llm|output_parser|RunnablePassthrough()

# %%
chain.invoke({"topic":"movies","question":"tell me about godfather movie"})
# Out:
# '"The Godfather" is a classic crime film directed by Francis Ford Coppola, released in 1972. It is based on the novel of the same name by Mario Puzo and follows the story of the powerful Italian-American mob family, the Corleones. The film stars Marlon Brando as Don Vito Corleone, the head of the family, and Al Pacino as his son Michael, who becomes increasingly involved in the family\'s criminal activities. \n\n"The Godfather" is widely regarded as one of the greatest films ever made, known for its strong performances, intricate storytelling, and iconic quotes. It has had a profound impact on popular culture and has spawned two sequels, "The Godfather Part II" and "The Godfather Part III."'

# %%
chain.output_schema.schema()
# Out:
# {'title': 'RunnablePassthroughOutput'}

# %%
new_chain=RunnablePassthrough()| RunnablePassthrough.assign(topic=lambda x:"movies")|prompt|llm|output_parser

# %%
test_chain=RunnablePassthrough()| RunnablePassthrough.assign(topic=lambda x:"movies")
test_chain.invoke({"question":"tell me about inception"})

#think it like you do nto want to expose the topic to teh user but just takje question from him
#but inclde more context through runnablepassthrough
# Out:
# {'question': 'tell me about inception', 'topic': 'movies'}
